# %%
from facebook_business.api import FacebookAdsApi
from facebook_business.adobjects.adaccount import AdAccount
from facebook_business.adobjects.adsinsights import AdsInsights

import gspread
from oauth2client.service_account import ServiceAccountCredentials

#Define scope
scope = ["https://www.googleapis.com/auth/spreadsheets",
         "https://www.googleapis.com/auth/drive"]

#Authenticate, create client
creds = ServiceAccountCredentials.from_json_keyfile_name('autoboard-wgg-39796a334267.json',scope)
client = gspread.authorize(creds)

#Open the sheet
spreadsheet = client.open("AutoDashTest")
worksheet = spreadsheet.sheet1

# credentials
ACCESS_TOKEN = 'EAAOqHuFGTDsBO9TRmUpkKkfOesnMjHm8vFZAEGynOmnmpUpG1nlTvZCsD2hwCFjoDxnK9SHZAfEvZB1LGmJ9xecU3U7hO3rSGXby7saZCBUQAHveZCnQ4ktOHGwWiIwCASasaX4u6kJ19rbqRO7N0QE0w7uhYPrhOJyOehaDRGNNW09ZAXyqS0fH0d9IFgWDuBn'  # Replace with your actual access token
AD_ACCOUNT_ID = 'act_261895734306797'

#Abbot & Oaks
#act_251614159192793
#DoggieLawn
#act_261895734306797

# Initialize the Facebook Ads API with your access token
FacebookAdsApi.init(access_token=ACCESS_TOKEN)

# Get the Ad Account object using  Ad Account ID
ad_account = AdAccount(AD_ACCOUNT_ID)

# Define the fields to retrieve (you can add more as needed)
fields = [
    AdsInsights.Field.campaign_name,        # Campaign name
    AdsInsights.Field.impressions,          # Number of impressions
    AdsInsights.Field.inline_link_clicks,               # Number of clicks
    AdsInsights.Field.spend,                # Total spend
]

# Fetch ad performance data
params = {
    'date_preset': 'last_7d',  # You can modify this to pull a custom date range (e.g., 'last_30d', 'this_month')
    'level': 'campaign',       # You can also pull data at the ad set or ad level if needed
}


# Fetch the performance data from the ad account
ads_data = ad_account.get_insights(fields=fields, params=params)

row_index = 2

for data in ads_data:
    cname = data.get(AdsInsights.Field.campaign_name, 'N/A')
    spd = data.get(AdsInsights.Field.spend, 'N/A')
    imp = data.get(AdsInsights.Field.impressions, 'N/A')
    clk = data.get(AdsInsights.Field.inline_link_clicks, 'N/A')
    row_data = [[cname, spd, imp, clk]]
    worksheet.update(row_data, f'A{row_index}:D{row_index}')
    row_index +=1
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File /opt/homebrew/Cellar/jupyterlab/4.1.5/libexec/lib/python3.12/site-packages/urllib3/connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File /opt/homebrew/Cellar/jupyterlab/4.1.5/libexec/lib/python3.12/site-packages/urllib3/util/connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
# ...

# %%
for data in ads_data:
    cname = data.get(AdsInsights.Field.campaign_name, 'N/A')
    spd = data.get(AdsInsights.Field.spend, 'N/A')
    imp = data.get(AdsInsights.Field.impressions, 'N/A')
    clk = data.get(AdsInsights.Field.inline_link_clicks, 'N/A')
    row_data = [[cname, spd, imp, clk]]
    worksheet.update(row_data, f'A{row_index}:D{row_index}')
    row_index +=1
